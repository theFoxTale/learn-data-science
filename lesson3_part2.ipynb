# %%
import pandas as pd

# %%
URL = "https://ru.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D1%81%D1%82%D0%B0%D0%BD%D1%86%D0%B8%D0%B9_%D0%9C%D0%BE%D1%81%D0%BA%D0%BE%D0%B2%D1%81%D0%BA%D0%BE%D0%B3%D0%BE_%D0%BC%D0%B5%D1%82%D1%80%D0%BE%D0%BF%D0%BE%D0%BB%D0%B8%D1%82%D0%B5%D0%BD%D0%B0"

# %%
data = pd.read_html(URL, attrs={"class": "standard sortable"}, header=0)

# %%
len(data)
# Out:
# 3

# %%
data[0]
# Out:
#      Unnamed: 0                   Название станцииПрежние названия  \
# 0           NaN  Бульвар РокоссовскогоУлица Подбельского (до 2014)
# 1           NaN                                       Черкизовская
# 2           NaN                             Преображенская площадь
# 3           NaN                                         Сокольники
# 4           NaN                                     Красносельская
# ..          ...                                                ...
# 234         NaN                                      Юго-Восточная
# 235         NaN                                             Косино
# 236         NaN                                Улица Дмитриевского
# 237         NaN                                       Лухмановская
# 238         NaN                                         Некрасовка
#
#         Датаоткрытия Пере-садки Глубина,м[2]  \
# 0     1 августа 1990        NaN           −8
# 1     1 августа 1990        NaN           −9
# 2    31 декабря 1965        NaN           −8
# 3        15 мая 1935        NaN           −9
# 4        15 мая 1935        NaN           −8
# ..               ...        ...          ...
# 234    27 марта 2020        NaN          −20
# 235      3 июня 2019        NaN          −27
# 236      3 июня 2019        NaN          −18
# 237      3 июня 2019        NaN          −15
# 238      3 июня 2019        NaN          −16
#
#                             Тип конструкции  \
# 0    колоннаямелкого заложениятрёхпролётная
# 1            односводчатаямелкого заложения
# 2    колоннаямелкого заложениятрёхпролётная
# 3    колоннаямелкого заложениятрёхпролётная
# 4    колоннаямелкого заложениядвухпролётная
# ..                                      ...
# 234  колоннаямелкого заложениядвухпролётная
# 235  колоннаямелкого заложениятрёхпролётная
# 236  колоннаямелкого заложениядвухпролётная
# 237  колоннаямелкого заложениятрёхпролётная
# 238  колоннаямелкого заложениядвухпролётная
#
#                             Координаты  Вид станции
# 0    55°48′53″ с. ш. 37°44′03″ в. д.HЯ          NaN
# 1    55°48′14″ с. ш. 37°44′41″ в. д.HЯ          NaN
# 2    55°47′47″ с. ш. 37°42′54″ в. д.HЯ          NaN
# 3    55°47′20″ с. ш. 37°40′49″ в. д.HЯ          NaN
# 4    55°46′48″ с. ш. 37°40′02″ в. д.HЯ          NaN
# ..                                 ...          ...
# 234                                  —          NaN
# 235                                  —          NaN
# 236                                  —          NaN
# 237                                  —          NaN
# 238                                  —          NaN
#
# [239 rows x 8 columns]
